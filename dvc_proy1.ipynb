# %%
pip install dvc
# Out:
# ...
#
# ...
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------------- -------------- 1.3/2.1 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/593.2 kB ? eta -:--:--
#    ---------------------------------------- 593.2/593.2 kB 5.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 3.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 2.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
# ...

# %%
dvc init
# Out:
#   Cell In[1], line 1
#     dvc init
#         ^
# SyntaxError: invalid syntax
